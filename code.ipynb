# %% [markdown]
# <h1><center><b><u><i> Heart Disease Prediction with Python Using all Supervised Machine Learning Algorithms for Binary Classification</i></u></b></center></h1>

# %% [markdown]
# ![image3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# We are going a build a Machine learning system that can predict whether a person has heart disease or not / diseased heart or not. So, this is the problem statement we have today.

# %% [markdown]
# ### <u>Project Work Flow</u>

# %% [markdown]
# ![work flow.png](data:image/png;base64,...)

# %% [markdown]
# Preventing heart disease has become more important than ever. Good data-driven systems for predicting cardiac illnesses can enhance the whole research and preventive process, allowing more people to enjoy healthy lives. This is where Machine Learning enters the picture.
# Machine Learning aids in the prognosis of heart illnesses, and the forecasts are extremely accurate.
#
# The project entailed analysing the heart disease patient dataset and properly processing the data. Then, several models are trained, and predictions are created using various techniques. KNN, Decision Tree, Random Forest, SVM, Logistic Regression, and more techniques.
#
# In this section, we will employ a range of machine learning algorithms written in Python to predict the existence of cardiac disease in a patient. This is a classification issue, with input characteristics represented as a set of parameters and the goal variable represented as a binary variable indicating whether or not heart disease exists.

# %% [markdown]
# 1.   The first step is to get the heart disease data.
#
# 2.   Next, we need to Process the data set. We cannot feed this raw data into our Machine learning algorithm. So, we need to process this data set to make it fit and compatible for our Machine Learning to learn.
#
# 3. In the third step, we need to spit our data into Training data and Testing data. Because we often train our machine learning algorithm with training data and we will evaluate the performance of our model using the test data. This part is called Train Test Split, where we will split our original data set into training data and test data.
#
# 4. In the fourth step, we will feed our training data to all supervised machine learning models. In this phase we will use following Machine Learning Algorithms as this particular use case is a Binary Classification, yes or no kind of question.
#
#   * Logistic Regression
#   * Naive Bayes
#   * Support Vector Machine
#   * K-Nearest Neighbors
#   * Decision Tree
#   * Random Forest
#   * XGBoost
#   * Neural Networks
#
# 5. Next, we need to Process the data set. We cannot feed this raw data into our Machine learning algorithms. So, we need to process this data set to make it fit and compatible for our Machine Learning model to learn.
#
# 5. Once we train this logistic regression model with our training data, we will do some evaluation on our model to check its performance.
#
# 6. Finally, we will get a trained Machine Learning model and to this model when we feed new data to our model so that it can predict whether that person has heart disease or not.
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### <u>Attribute Information:</u>
#
# <ol>
#     <li>age: age in years</li>
#     <li>sex: sex / gender</li>
#     <ul>
#         <li> 1 = male</li>
#         <li>0 = female</li>
#     </ul>
#     <li>cp: chest pain type</li>
#     <ul>
#         <li>Value 0: typical angina</li>
#         <li>Value 1: atypical angina</li>
#         <li>Value 2: non-anginal pain</li>
#         <li>Value 3: asymptomatic</li>
#     </ul>
#     <li>trestbps: resting blood pressure (in mm Hg on admission to the hospital)</li>
#     <li>chol: serum cholestoral in mg/dl</li>
#     <li>fbs: (fasting blood sugar > 120 mg/dl)</li>
#     <ul>
#         <li>1 = true</li>
#         <li>0 = false</li>
#     </ul>
#     <li>restecg: resting electrocardiographic results</li>
#     <ul>
#         <li>Value 0: normal</li>
#         <li>Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)</li>
#         <li>Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria</li>
#     </ul>
#     <li>thalach: maximum heart rate achieved</li>
#     <li>exang: exercise induced angina</li>
#     <ul>
#         <li>1 = yes</li>
#         <li>0 = no</li>
#     </ul>
#     <li>oldpeak = ST depression induced by exercise relative to rest</li>
#     <li>slope: the slope of the peak exercise ST segment</li>
#     <ul>
#         <li>Value 0: upsloping</li>
#         <li>Value 1: flat</li>
#         <li>Value 2: downsloping</li>
#     </ul>
#     <li>ca: number of major vessels (0-3) colored by flourosopy</li>
#     <li>thal:</li>
#     <ul>
#         <li>0 = error (in the original dataset 0 maps to NaN's)</li>
#         <li>1 = fixed defect</li>
#         <li>2 = normal</li>
#         <li>3 = reversable defect</li>
#     </ul>
#     <li>target (the lable):</li>
#     <ul>
#         <li>0 = no disease</li>
#         <li>1 = disease</li>
#     </ul>
# </ol>
#
# * Here in 9th point Angina means, pain in the heart which caused due to low blood in the heart when a person is exercising.
# * ST depression and ST segment is based on the ECG or Eco-2D curves as shown in the below figure.

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ##### Schematic diagram of normal sinus rhythm for a human heart as seen on ECG or Eco-2D

# %% [markdown]
# ![image2.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# <h1><center><b><u>Actual Code </u></b></center></h1>
#
#
# ---
#
#
#
# ---

# %% [markdown]
# Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.config', 'heart.csv', 'sample_data']

# %% [markdown]
# ***Data Collection and Processing***
#
# Importing and understanding our dataset

# %%
dataset = pd.read_csv("heart.csv")

# %% [markdown]
# Verifying it as a 'dataframe' object in pandas

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Shape of dataset

# %%
dataset.shape
# Out:
# (303, 14)

# %% [markdown]
# Printing out a few columns

# %%
dataset.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
dataset.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 33    54    1   2       125   273    0        0      152      0      0.5
# 269   56    1   0       130   283    1        0      103      1      1.6
# 41    48    1   1       130   245    0        0      180      0      0.2
# 45    52    1   1       120   325    0        1      172      0      0.2
# 189   41    1   0       110   172    0        0      158      0      0.0
#
#      slope  ca  thal  target
# 33       0   1     2       1
# 269      0   0     3       0
# 41       1   0     2       1
# 45       2   0     2       1
# 189      2   0     3       0

# %% [markdown]
# Analyze data more....

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
###Luckily, we have no missing values

# %% [markdown]
# Analysing the 'target' variable

# %%
dataset["target"].describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# Clearly, this is a classification problem, with the target variable having values '0' and '1'

# %% [markdown]
# Checking correlation between columns

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %%
#This shows that most columns are moderately correlated with target, but 'fbs' is very weakly correlated.

# %% [markdown]
# ***Exploratory Data Analysis (EDA)***

# %% [markdown]
# First, analysing the target variable:

# %%
y = dataset["target"]

sns.countplot(y)


target_temp = dataset.target.value_counts()

print(target_temp)
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# The importance of finding the above distribution and counts values are,
# * We need to have an almost equal number of distribution in the two classes (0-class and 1-class).
# * Here in this case it is almost equal in terms of percentage.
# * But if there are about 80% of values lie in one class and if 20% in another class, then it is a problem where we need to do some processing.

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/303,2)))

#Alternatively,
# print("Percentage of patience with heart problems: "+str(y.where(y==1).count()*100/303))
# print("Percentage of patience with heart problems: "+str(y.where(y==0).count()*100/303))

# #Or,
# countNoDisease = len(df[df.target == 0])
# countHaveDisease = len(df[df.target == 1])
# Out:
# Percentage of patience without heart problems: 45.54
# Percentage of patience with heart problems: 54.46

# %% [markdown]
# We'll analyse following features ::
#
# 1. sex
# 2. cp
# 3. fbs
# 4. restecg
# 5. exang
# 6. slope
# 7. ca
# 8. thal

# %% [markdown]
# ***1. Analysing the 'Sex' feature***

# %%
dataset["sex"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# We notice, that as expected, the 'sex' feature has 2 unique features

# %%
sns.barplot(dataset["sex"],y)

# %% [markdown]
# We notice, that females are more likely to have heart problems than males

# %% [markdown]
# ***2. Analysing the 'Chest Pain Type (cp)' feature***

# %%
dataset["cp"].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# As expected, the CP feature has values from 0 to 3

# %%
sns.barplot(dataset["cp"],y)

# %% [markdown]
# We notice, that chest pain of '0', i.e. the ones with typical angina are much less likely to have heart problems

# %% [markdown]
# ***3. Analysing the 'FBS' feature***

# %%
dataset["fbs"].describe()
# Out:
# count    303.000000
# mean       0.148515
# std        0.356198
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([1, 0])

# %%
sns.barplot(dataset["fbs"],y)

# %% [markdown]
# ***4. Analysing the 'restecg' feature***

# %%
dataset["restecg"].unique()
# Out:
# array([0, 1, 2])

# %%
sns.barplot(dataset["restecg"],y)

# %% [markdown]
# We realize that people with restecg '1' and '0' are much more likely to have a heart disease than with restecg '2'

# %% [markdown]
# ***5. Analysing the 'exang' feature***

# %%
dataset["exang"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(dataset["exang"],y)

# %% [markdown]
# People with exang=1 i.e. Exercise induced angina are much less likely to have heart problems

# %% [markdown]
# ***6. Analysing the 'Slope' feature***

# %%
dataset["slope"].unique()
# Out:
# array([0, 2, 1])

# %%
sns.barplot(dataset["slope"],y)

# %% [markdown]
# We observe, that Slope '2' causes heart pain much more than Slope '0' and '1'

# %% [markdown]
# ***7. Analysing the 'ca' feature***

# %%
#number of major vessels (0-3) colored by flourosopy

# %%
dataset["ca"].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
sns.countplot(dataset["ca"])

# %%
sns.barplot(dataset["ca"],y)

# %% [markdown]
# ca=4 has astonishingly large number of heart patients

# %% [markdown]
# ***8. Analysing the 'thal' feature***

# %%
dataset["thal"].unique()
# Out:
# array([1, 2, 3, 0])

# %%
sns.barplot(dataset["thal"],y)

# %%
sns.distplot(dataset["thal"])

# %% [markdown]
# **Splitting the Data into Training data & Test Data**

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
Y_train.shape
# Out:
# (242,)

# %%
Y_test.shape
# Out:
# (61,)

# %% [markdown]
# **Model Fitting & Model Evaluation**
# * We are going to use Accuracy Score as our Evaluaution Metric
# * Here the model will be asked to predict the target and this predicted value is compared with the original.
# * Let's say we are predicting for 100 values.
# * for those 100 values the model is predicte correctly for 95 values.
# * in this case the accuracy score is 95 percentage
# * if the model is predicted for 60 values, in that case the accuracy score is 60 percentage.
# * Accuracy more than 75 percentage is somewhat good.
# * We may get more accuracy if we use large data set.
# * It is very important to have almost equal accuracy score for both training data and test data.
# * If it is hich for training data and it is very low for testing data, then it leads to 'OverFitting'.
# * Here we are using following Machine Learning Algorithms.
#    1. Logistic Regression
#    2. Naive Bayes
#    3. SVM
#    4. K-Nearest Neighbors
#    5. Decision Tree
#    6. Random Forest
#    7. XGBoost
#    8. Neural Network

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ***1. Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %

# %% [markdown]
# **2. Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (61,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.25 %

# %% [markdown]
# ***3. SVM***

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (61,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.97 %

# %% [markdown]
# **4. K-Nearest Neighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (61,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %% [markdown]
# ***5. Decision Tree***

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (61,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.97 %

# %% [markdown]
# ***6. Random Forest***

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (61,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 90.16 %

# %% [markdown]
# ***7. XGBoost***

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (61,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 85.25 %

# %% [markdown]
# ***8. Neural Network***

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 47ms/step - loss: 70.0521 - accuracy: 0.5413
# Epoch 2/300
# 8/8 [==============================] - 0s 2ms/step - loss: 62.2586 - accuracy: 0.5413
# Epoch 3/300
# 8/8 [==============================] - 0s 3ms/step - loss: 54.4912 - accuracy: 0.5413
# Epoch 4/300
# 8/8 [==============================] - 0s 2ms/step - loss: 46.6424 - accuracy: 0.5413
# Epoch 5/300
# 8/8 [==============================] - 0s 3ms/step - loss: 38.5435 - accuracy: 0.5413
# Epoch 6/300
# 8/8 [==============================] - 0s 2ms/step - loss: 30.4208 - accuracy: 0.5413
# Epoch 7/300
# 8/8 [==============================] - 0s 3ms/step - loss: 22.0004 - accuracy: 0.5413
# Epoch 8/300
# 8/8 [==============================] - 0s 2ms/step - loss: 13.3895 - accuracy: 0.5413
# Epoch 9/300
# 8/8 [==============================] - 0s 2ms/step - loss: 4.9886 - accuracy: 0.5496
# Epoch 10/300
# ...

# %%
Y_pred_nn = model.predict(X_test)

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")

#Note: Accuracy of 85% can be achieved on the test set, by setting epochs=2000, and number of nodes = 11.
# Out:
# The accuracy score achieved using Neural Network is: 81.97 %

# %% [markdown]
# **Output final score - Comparing all Machine Learning Algorithms**

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+"--------> "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression--------> 85.25 %
# The accuracy score achieved using Naive Bayes--------> 85.25 %
# The accuracy score achieved using Support Vector Machine--------> 81.97 %
# The accuracy score achieved using K-Nearest Neighbors--------> 67.21 %
# The accuracy score achieved using Decision Tree--------> 81.97 %
# The accuracy score achieved using Random Forest--------> 90.16 %
# The accuracy score achieved using XGBoost--------> 85.25 %
# The accuracy score achieved using Neural Network--------> 81.97 %

# %%
sns.set(rc={'figure.figsize':(19,6)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")
sns.barplot(algorithms,scores, data=dataset)

# %% [markdown]
# ***Building a Predictive System and let's test it using Machine learning Algorithm which has high Accuracy rate (In this case it is Random Forest).***

# %%
def let_us_test(input_data):
    # asarray function converts into a numpy array
    input_data_as_numpy_array= np.asarray(input_data)

    # reshape the numpy array as we are predicting for only on instance
    # otherwise our model will predict for all the features in tha data set 
    input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

    
    prediction = rf.predict(input_data_reshaped)
    print(f'Column Target value for the input features \n{input_data} is : ', prediction)

    if (prediction[0]== 0):
      print('\nThe Person does not have a Heart Disease')
    else:
      print('\nThe Person has Heart Disease')

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2) # The Person does not have a Heart Disease
# input_data = (63,1,3,145,233,1,0,150,0,2.3,2,0,2 ) # The Person has Heart Disease
# change the input data to a numpy array
let_us_test(input_data)
